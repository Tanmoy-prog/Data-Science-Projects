# %%
import pandas as pd
import numpy as np

# %%
sal = pd.read_csv('Salary_Data.csv')

# %%
import statsmodels.api as sm

# %%
from sklearn.datasets import load_boston

# %%
df = load_boston()

# %%
d=pd.DataFrame(df.data)

# %%
d.columns=df.feature_names

# %%
d.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000

# %%
y=pd.DataFrame(df.target,columns=['price'])

# %%
y
# Out:
#      price
# 0     24.0
# 1     21.6
# 2     34.7
# 3     33.4
# 4     36.2
# ..     ...
# 501   22.4
# 502   20.6
# 503   23.9
# 504   22.0
# 505   11.9
#
# [506 rows x 1 columns]

# %%
d=sm.add_constant(d)

# %%
d
# Out:
#      const     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0      1.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1      1.0  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2      1.0  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3      1.0  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4      1.0  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..     ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501    1.0  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502    1.0  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503    1.0  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504    1.0  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505    1.0  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO       B  LSTAT
# 0    296.0     15.3  396.90   4.98
# 1    242.0     17.8  396.90   9.14
# 2    242.0     17.8  392.83   4.03
# 3    222.0     18.7  394.63   2.94
# 4    222.0     18.7  396.90   5.33
# ..     ...      ...     ...    ...
# 501  273.0     21.0  391.99   9.67
# 502  273.0     21.0  396.90   9.08
# 503  273.0     21.0  396.90   5.64
# 504  273.0     21.0  393.45   6.48
# 505  273.0     21.0  396.90   7.88
#
# [506 rows x 14 columns]

# %%
o = sm.OLS(y,d).fit()

# %%
o.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):          6.72e-135
# Time:                        14:05:08   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.4595      5.103      7.144      0.000      26.432      46.487
# CRIM          -0.1080      0.033     -3.287      0.001      -0.173      -0.043
# ZN             0.0464      0.014      3.382      0.001       0.019       0.073
# INDUS          0.0206      0.061      0.334      0.738      -0.100       0.141
# CHAS           2.6867      0.862      3.118      0.002       0.994       4.380
# NOX          -17.7666      3.820     -4.651      0.000     -25.272     -10.262
# RM             3.8099      0.418      9.116      0.000       2.989       4.631
# AGE            0.0007      0.013      0.052      0.958      -0.025       0.027
# DIS           -1.4756      0.199     -7.398      0.000      -1.867      -1.084
# RAD            0.3060      0.066      4.613      0.000       0.176       0.436
# TAX           -0.0123      0.004     -3.280      0.001      -0.020      -0.005
# PTRATIO       -0.9527      0.131     -7.283      0.000      -1.210      -0.696
# B              0.0093      0.003      3.467      0.001       0.004       0.015
# LSTAT         -0.5248      0.051    -10.347      0.000      -0.624      -0.425
# ==============================================================================
# Omnibus:                      178.041   Durbin-Watson:                   1.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              783.126
# Skew:                           1.521   Prob(JB):                    8.84e-171
# Kurtosis:                       8.281   Cond. No.                     1.51e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
s=d.corr()

# %%
plt.figure(figsize=[20,10])
sns.heatmap(s,annot=True)

# %%
d1=pd.DataFrame(df.data)

# %%
d1.columns=df.feature_names

# %%
d1.drop('TAX',axis=1,inplace=True)

# %%
d1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0     15.3
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0     17.8
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0     17.8
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0     18.7
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0     18.7
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...      ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0     21.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0     21.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0     21.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0     21.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0     21.0
#
#           B  LSTAT
# 0    396.90   4.98
# 1    396.90   9.14
# 2    392.83   4.03
# 3    394.63   2.94
# 4    396.90   5.33
# ..      ...    ...
# 501  391.99   9.67
# 502  396.90   9.08
# 503  396.90   5.64
# 504  393.45   6.48
# 505  396.90   7.88
#
# [506 rows x 12 columns]

# %%
d1=sm.add_constant(d1)

# %%
w=sm.OLS(y,d1).fit()

# %%
w.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                     113.9
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):          1.21e-133
# Time:                        14:17:18   Log-Likelihood:                -1504.3
# No. Observations:                 506   AIC:                             3035.
# Df Residuals:                     493   BIC:                             3089.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         34.6286      5.123      6.760      0.000      24.563      44.694
# CRIM          -0.1067      0.033     -3.216      0.001      -0.172      -0.042
# ZN             0.0364      0.014      2.692      0.007       0.010       0.063
# INDUS         -0.0678      0.056     -1.214      0.225      -0.177       0.042
# CHAS           3.0292      0.864      3.507      0.000       1.332       4.726
# NOX          -18.7012      3.847     -4.862      0.000     -26.259     -11.143
# RM             3.9117      0.421      9.294      0.000       3.085       4.739
# AGE           -0.0006      0.013     -0.045      0.964      -0.027       0.026
# DIS           -1.4883      0.201     -7.390      0.000      -1.884      -1.093
# RAD            0.1346      0.041      3.262      0.001       0.054       0.216
# PTRATIO       -0.9851      0.132     -7.478      0.000      -1.244      -0.726
# B              0.0095      0.003      3.521      0.000       0.004       0.015
# LSTAT         -0.5222      0.051    -10.198      0.000      -0.623      -0.422
# ==============================================================================
# Omnibus:                      168.699   Durbin-Watson:                   1.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              702.173
# Skew:                           1.452   Prob(JB):                    3.35e-153
# Kurtosis:                       7.987   Cond. No.                     1.01e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
a=d1.corr()
a
# Out:
#          const      CRIM        ZN     INDUS      CHAS       NOX        RM  \
# const      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# CRIM       NaN  1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN         NaN -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS      NaN  0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS       NaN -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX        NaN  0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM         NaN -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE        NaN  0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS        NaN -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD        NaN  0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# PTRATIO    NaN  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# B          NaN -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# LSTAT      NaN  0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808
#
#               AGE       DIS       RAD   PTRATIO         B     LSTAT
# const         NaN       NaN       NaN       NaN       NaN       NaN
# CRIM     0.352734 -0.379670  0.625505  0.289946 -0.385064  0.455621
# ZN      -0.569537  0.664408 -0.311948 -0.391679  0.175520 -0.412995
# INDUS    0.644779 -0.708027  0.595129  0.383248 -0.356977  0.603800
# CHAS     0.086518 -0.099176 -0.007368 -0.121515  0.048788 -0.053929
# NOX      0.731470 -0.769230  0.611441  0.188933 -0.380051  0.590879
# RM      -0.240265  0.205246 -0.209847 -0.355501  0.128069 -0.613808
# AGE      1.000000 -0.747881  0.456022  0.261515 -0.273534  0.602339
# DIS     -0.747881  1.000000 -0.494588 -0.232471  0.291512 -0.496996
# RAD      0.456022 -0.494588  1.000000  0.464741 -0.444413  0.488676
# PTRATIO  0.261515 -0.232471  0.464741  1.000000 -0.177383  0.374044
# B       -0.273534  0.291512 -0.444413 -0.177383  1.000000 -0.366087
# LSTAT    0.602339 -0.496996  0.488676  0.374044 -0.366087  1.000000

# %%
a.iloc[1,3]
# Out:
# 0.4065834114062593
